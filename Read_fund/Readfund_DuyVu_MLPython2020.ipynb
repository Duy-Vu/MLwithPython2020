# %%
import requests
import pandas as pd

# %%
# Demo on getting total fund from 1 person

full_name = "Patric Östergård"
names = full_name.split(' ')
first = names[0] 
last = names[1]
    
url = f"https://akareport.aka.fi/ibi_apps/WFServlet?ekaLataus=0&IBIF_ex=x_RahPaatYht_report2&UILANG=en&SANAHAKU=&ETUNIMI={first}&SUKUNIMI={last}&SUKUPUOLI=FOC_NONE&HAKU=FOC_NONE&ORGANIS=FOC_NONE&TUTKDI=FOC_NONE&TMK=FOC_NONE&PAATVUOSI_A=2001&PAATVUOSI_L=2020&LAJITTELU=PAATOS&TULOSTE=HTML"
website = requests.get(url).content

raw_df = pd.read_html(website, index_col=0, skiprows=5, keep_default_na=False)[0]
raw_df
# Out:
#
# Year of decision:                                                                           2001-2020
# First name:                                                                                    Patric
# Surname:                                                                                    Östergård
# Project count:                                                                                      7
# Project funding:                                                                          1 926 713 €
#
#
# Applicant / Contact person                                                               Organisation
#
# Academy Project LT Research Council communicati...  Academy Project LT Research Council communicat...
# Östergård, Patric                                                                    Aalto University
#
# Basic research in programming, algorithms and t...  Basic research in programming, algorithms and ...
# Östergård, Patric                                                                    Aalto University
#
# General application for research appropriations LT  General application for research appropriation...
# Östergård, Patric                                                                    Aalto University
#
# Määrärahat varttuneen tutkijan palkkaukseen LT         Määrärahat varttuneen tutkijan palkkaukseen LT
# Östergård, Patric                                                                    Aalto University
#
# Tutkimusmäärärahojen yleinen haku LT                             Tutkimusmäärärahojen yleinen haku LT
# Östergård, Patric                                                                    Aalto University
#
# Varttuneen tutkijan palkkaus- ja tutkimuskulut LT   Varttuneen tutkijan palkkaus- ja tutkimuskulut LT
# Östergård, Patric                                                                    Aalto University
#
# Yleiset tutkimusmäärärahat LT                                           Yleiset tutkimusmäärärahat LT
# Östergård, Patric                                                                    Aalto University
#
#
#                                                                                                     2  \
# 0
# Year of decision:                                                                           2001-2020
# First name:                                                                                    Patric
# Surname:                                                                                    Östergård
# Project count:                                                                                      7
# Project funding:                                                                          1 926 713 €
#
#
# Applicant / Contact person                                                              Project title
#
# Academy Project LT Research Council communicati...  Academy Project LT Research Council communicat...
# Östergård, Patric                                   Construction and Classification of Discrete Ma...
#
# Basic research in programming, algorithms and t...  Basic research in programming, algorithms and ...
# Östergård, Patric                                                           Kombinatoriset algoritmit
#
# General application for research appropriations LT  General application for research appropriation...
# Östergård, Patric                                   Codes and Algorithms for Error Control in Digi...
#
# Määrärahat varttuneen tutkijan palkkaukseen LT         Määrärahat varttuneen tutkijan palkkaukseen LT
# Östergård, Patric                                   Laskennalliset menetelmät diskreetissä matemat...
#
# Tutkimusmäärärahojen yleinen haku LT                             Tutkimusmäärärahojen yleinen haku LT
# Östergård, Patric                                        Computational Methods int Telecommunications
#
# Varttuneen tutkijan palkkaus- ja tutkimuskulut LT   Varttuneen tutkijan palkkaus- ja tutkimuskulut LT
# Östergård, Patric                                             Combinatorial Structures and Algorithms
#
# Yleiset tutkimusmäärärahat LT                                           Yleiset tutkimusmäärärahat LT
# Östergård, Patric                                       Mathematical Structures in Telecommunications
#
#
#                                                                                                     3  \
# 0
# Year of decision:                                                                           2001-2020
# First name:                                                                                    Patric
# Surname:                                                                                    Östergård
# Project count:                                                                                      7
# Project funding:                                                                          1 926 713 €
#
#
# Applicant / Contact person                                                               Decision No.
#
# Academy Project LT Research Council communicati...  Academy Project LT Research Council communicat...
# Östergård, Patric                                                                              289002
#
# Basic research in programming, algorithms and t...  Basic research in programming, algorithms and ...
# Östergård, Patric                                                                              107493
#
# General application for research appropriations LT  General application for research appropriation...
# Östergård, Patric                                                                              110196
#
# Määrärahat varttuneen tutkijan palkkaukseen LT         Määrärahat varttuneen tutkijan palkkaukseen LT
# Östergård, Patric                                                                              103080
#
# Tutkimusmäärärahojen yleinen haku LT                             Tutkimusmäärärahojen yleinen haku LT
# Östergård, Patric                                                                              100710
#
# Varttuneen tutkijan palkkaus- ja tutkimuskulut LT   Varttuneen tutkijan palkkaus- ja tutkimuskulut LT
# Östergård, Patric                                                                              130142
#
# Yleiset tutkimusmäärärahat LT                                           Yleiset tutkimusmäärärahat LT
# Östergård, Patric                                                                              132122
#
#
#                                                                                                     4  \
# 0
# Year of decision:                                                                           2001-2020
# First name:                                                                                    Patric
# Surname:                                                                                    Östergård
# Project count:                                                                                      7
# Project funding:                                                                          1 926 713 €
#
#
# Applicant / Contact person                                                              Decision date
#
# Academy Project LT Research Council communicati...  Academy Project LT Research Council communicat...
# Östergård, Patric                                                                          11.06.2015
#
# Basic research in programming, algorithms and t...  Basic research in programming, algorithms and ...
# Östergård, Patric                                                                          15.11.2004
#
# General application for research appropriations LT  General application for research appropriation...
# Östergård, Patric                                                                          18.11.2005
#
# Määrärahat varttuneen tutkijan palkkaukseen LT         Määrärahat varttuneen tutkijan palkkaukseen LT
# Östergård, Patric                                                                          11.04.2003
#
# Tutkimusmäärärahojen yleinen haku LT                             Tutkimusmäärärahojen yleinen haku LT
# Östergård, Patric                                                                          19.11.2001
#
# Varttuneen tutkijan palkkaus- ja tutkimuskulut LT   Varttuneen tutkijan palkkaus- ja tutkimuskulut LT
# Östergård, Patric                                                                          05.02.2009
#
# Yleiset tutkimusmäärärahat LT                                           Yleiset tutkimusmäärärahat LT
# Östergård, Patric                                                                          29.09.2009
#
#
#                                                                                                     5  \
# 0
# Year of decision:                                                                           2001-2020
# First name:                                                                                    Patric
# Surname:                                                                                    Östergård
# Project count:                                                                                      7
# Project funding:                                                                          1 926 713 €
#
#
# Applicant / Contact person                                                             Funding period
#
# Academy Project LT Research Council communicati...  Academy Project LT Research Council communicat...
# Östergård, Patric                                                             01.09.2015 - 31.08.2019
#
# Basic research in programming, algorithms and t...  Basic research in programming, algorithms and ...
# Östergård, Patric                                                             01.01.2005 - 31.12.2008
#
# General application for research appropriations LT  General application for research appropriation...
# Östergård, Patric                                                             01.01.2006 - 31.12.2009
#
# Määrärahat varttuneen tutkijan palkkaukseen LT         Määrärahat varttuneen tutkijan palkkaukseen LT
# Östergård, Patric                                                             01.08.2003 - 31.12.2004
#
# Tutkimusmäärärahojen yleinen haku LT                             Tutkimusmäärärahojen yleinen haku LT
# Östergård, Patric                                                             01.01.2002 - 31.12.2005
#
# Varttuneen tutkijan palkkaus- ja tutkimuskulut LT   Varttuneen tutkijan palkkaus- ja tutkimuskulut LT
# Östergård, Patric                                                             01.08.2009 - 31.12.2010
#
# Yleiset tutkimusmäärärahat LT                                           Yleiset tutkimusmäärärahat LT
# Östergård, Patric                                                             01.01.2010 - 31.12.2013
#
#
#                                                                                                     6
# 0
# Year of decision:                                                                           2001-2020
# First name:                                                                                    Patric
# Surname:                                                                                    Östergård
# Project count:                                                                                      7
# Project funding:                                                                          1 926 713 €
#
#
# Applicant / Contact person
#
# Academy Project LT Research Council communicati...  Academy Project LT Research Council communicat...
# Östergård, Patric                                                                             663 502
#
# Basic research in programming, algorithms and t...  Basic research in programming, algorithms and ...
# Östergård, Patric                                                                             217 600
#
# General application for research appropriations LT  General application for research appropriation...
# Östergård, Patric                                                                             171 200
#
# Määrärahat varttuneen tutkijan palkkaukseen LT         Määrärahat varttuneen tutkijan palkkaukseen LT
# Östergård, Patric                                                                             100 360
#
# Tutkimusmäärärahojen yleinen haku LT                             Tutkimusmäärärahojen yleinen haku LT
# Östergård, Patric                                                                             242 192
#
# Varttuneen tutkijan palkkaus- ja tutkimuskulut LT   Varttuneen tutkijan palkkaus- ja tutkimuskulut LT
# Östergård, Patric                                                                             126 860
#
# Yleiset tutkimusmäärärahat LT                                           Yleiset tutkimusmäärärahat LT
# Östergård, Patric                                                                             404 999

# %%
# Get the fund result as string
fund_df = raw_df.loc["Project funding:"]
fund_value = fund_df.iloc[1]
fund_value
# Out:
# '1 926 713 €'

# %%
# Get names stored in text file 
# This is an optional function in case you want to store researchers' name in text file
def get_name(file_name):
    """
    Get researchers' names from text file
    :param file_name: name of the file storing researchers' names
    :return name_list: list of names
    """

    list_names = []
    with open(file_name, 'r') as file:
        for name in file:
            name = name.strip()
            list_names.append(name)

    return list_names

# %%
# Get fund value from "Academy of Finland" webpage
def get_fund(full_name):
    """
    Get funding amount given name of applicants/researchers
    :param name: full name applicants in the form "<First name> <Surname/Lastname>" (e.g "Arno Solin")
    :return fund_value: total fund
    """

    names = full_name.split(' ')
    first = names[0] 
    last = names[1]
    
    url = f"https://akareport.aka.fi/ibi_apps/WFServlet?ekaLataus=0&IBIF_ex=x_RahPaatYht_report2&UILANG=en&SANAHAKU=&ETUNIMI={first}&SUKUNIMI={last}&SUKUPUOLI=FOC_NONE&HAKU=FOC_NONE&ORGANIS=FOC_NONE&TUTKDI=FOC_NONE&TMK=FOC_NONE&PAATVUOSI_A=2001&PAATVUOSI_L=2020&LAJITTELU=PAATOS&TULOSTE=HTML"
    website = requests.get(url).content

    try:
        raw_df = pd.read_html(website, index_col=0, skiprows=5, keep_default_na=False)[0]
        fund_value = raw_df.loc["Project funding:"].iloc[1]
        fund_value = fund_value.replace(' €', '')
    except:
        # Name not exist
        fund_value = "0"

    return fund_value

# %%
# name_list = get_name("applicant_list.txt") # Using this function if names are store in text file
name_list = ["Jaakko Lehtinen", "Patric Östergård", "Arno Solin", "Stavros Tripakis", "Duy Vu"]

fund_list = []
for name in name_list:
    fund_list.append(get_fund(name))

df = pd.DataFrame({"Researcher name": name_list, "Total fund (€)": fund_list})
df
# Out:
#     Researcher name Total fund (€)
# 0   Jaakko Lehtinen        495 326
# 1  Patric Östergård      1 926 713
# 2        Arno Solin        653 212
# 3  Stavros Tripakis        413 171
# 4            Duy Vu              0

# %%
# ALgin content in dataframe to the left
df_left_align = df.style.set_properties(**{'text-align': 'left'})
df_left_align.set_table_styles([dict(selector='th', props=[('text-align', 'left')])])
df_left_align
# Out:
# <style  type="text/css" >
#     #T_f1cbb49c_a345_11ea_b776_107d1a3c68e9 th {
#           text-align: left;
#     }    #T_f1cbb49c_a345_11ea_b776_107d1a3c68e9row0_col0 {
#             text-align:  left;
#         }    #T_f1cbb49c_a345_11ea_b776_107d1a3c68e9row0_col1 {
#             text-align:  left;
#         }    #T_f1cbb49c_a345_11ea_b776_107d1a3c68e9row1_col0 {
#             text-align:  left;
#         }    #T_f1cbb49c_a345_11ea_b776_107d1a3c68e9row1_col1 {
#             text-align:  left;
#         }    #T_f1cbb49c_a345_11ea_b776_107d1a3c68e9row2_col0 {
#             text-align:  left;
#         }    #T_f1cbb49c_a345_11ea_b776_107d1a3c68e9row2_col1 {
#             text-align:  left;
#         }    #T_f1cbb49c_a345_11ea_b776_107d1a3c68e9row3_col0 {
#             text-align:  left;
#         }    #T_f1cbb49c_a345_11ea_b776_107d1a3c68e9row3_col1 {
#             text-align:  left;
#         }    #T_f1cbb49c_a345_11ea_b776_107d1a3c68e9row4_col0 {
#             text-align:  left;
#         }    #T_f1cbb49c_a345_11ea_b776_107d1a3c68e9row4_col1 {
#             text-align:  left;
#         }</style><table id="T_f1cbb49c_a345_11ea_b776_107d1a3c68e9" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Researcher name</th>        <th class="col_heading level0 col1" >Total fund (€)</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_f1cbb49c_a345_11ea_b776_107d1a3c68e9level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_f1cbb49c_a345_11ea_b776_107d1a3c68e9row0_col0" class="data row0 col0" >Jaakko Lehtinen</td>
#                         <td id="T_f1cbb49c_a345_11ea_b776_107d1a3c68e9row0_col1" class="data row0 col1" >495 326</td>
#             </tr>
#             <tr>
#                         <th id="T_f1cbb49c_a345_11ea_b776_107d1a3c68e9level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_f1cbb49c_a345_11ea_b776_107d1a3c68e9row1_col0" class="data row1 col0" >Patric Östergård</td>
#                         <td id="T_f1cbb49c_a345_11ea_b776_107d1a3c68e9row1_col1" class="data row1 col1" >1 926 713</td>
#             </tr>
#             <tr>
#                         <th id="T_f1cbb49c_a345_11ea_b776_107d1a3c68e9level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_f1cbb49c_a345_11ea_b776_107d1a3c68e9row2_col0" class="data row2 col0" >Arno Solin</td>
#                         <td id="T_f1cbb49c_a345_11ea_b776_107d1a3c68e9row2_col1" class="data row2 col1" >653 212</td>
#             </tr>
#             <tr>
#                         <th id="T_f1cbb49c_a345_11ea_b776_107d1a3c68e9level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_f1cbb49c_a345_11ea_b776_107d1a3c68e9row3_col0" class="data row3 col0" >Stavros Tripakis</td>
#                         <td id="T_f1cbb49c_a345_11ea_b776_107d1a3c68e9row3_col1" class="data row3 col1" >413 171</td>
#             </tr>
#             <tr>
#                         <th id="T_f1cbb49c_a345_11ea_b776_107d1a3c68e9level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_f1cbb49c_a345_11ea_b776_107d1a3c68e9row4_col0" class="data row4 col0" >Duy Vu</td>
#                         <td id="T_f1cbb49c_a345_11ea_b776_107d1a3c68e9row4_col1" class="data row4 col1" >0</td>
#             </tr>
#     </tbody></table>
